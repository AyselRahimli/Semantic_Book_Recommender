# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import warnings
warnings.filterwarnings("ignore")
import kagglehub
from kagglehub import KaggleDatasetAdapter
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")
books = pd.read_csv(f"{path}/books.csv")
# Out:
# Using Colab cache for faster access to the '7k-books-with-metadata' dataset.

# %%
import pandas as pd

# %%
books = df

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = plt.axes()
sns.heatmap(df.isna().transpose(), cbar = False, ax=ax)
plt.xlabel('columns')
plt.ylabel('Missing values')
plt.show()

# %%
import numpy as np
df["missing_desc"] = np.where(df['description'].isna(),1,0)
df["age_of_book"] = 2026 - df['published_year']
columns_of_interest = ['num_pages','age_of_book','missing_desc','average_rating']

# %%
corr_matrix = df[columns_of_interest].corr(method = 'spearman')
sns.set_theme(style = 'white')
plt.figure(figsize = (8,10))
heatmap = sns.heatmap(corr_matrix, annot = True, cmap = 'Blues')
heatmap.set_title('Correlation Heatmap', fontdict = {'fontsize':12}, pad = 12)
plt.show()

# %% [markdown]
# weak correlation of missing_desc
# it shows that it does not really matter

# %%
df[(df['description'].isna()) | (df['num_pages'].isna()) | (df['average_rating'].isna())| (df['published_year'].isna())]
# Out:
#              isbn13      isbn10  \
# 37    9780006906018  000690601X
# 60    9780007127740  000712774X
# 99    9780020442806  0020442807
# 102   9780023513206  0023513209
# 105   9780026995016  0026995018
# ...             ...         ...
# 6787  9783464371640  3464371646
# 6788  9783540292128  3540292128
# 6798  9787506435673  7506435675
# 6806  9788185944609  8185944601
# 6807  9788445074879  8445074873
#
#                                                   title  \
# 37                    The Princess of the Chalet School
# 60                                  The illustrated man
# 99    The Chronicles of Narnia: Lion, the witch and ...
# 102                                   Reason in History
# 105                                             Spandau
# ...                                                 ...
# 6787                                        About a Boy
# 6788             Enzyme-Catalyzed Synthesis of Polymers
# 6798                                         Good Fight
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
book_missing = books[~(books["description"].isna()) &
      ~(books["num_pages"].isna()) &
      ~(books["average_rating"].isna()) &
      ~(books["published_year"].isna())
]

# %% [markdown]
# this is like one of the mentioned columns are incomplete, we are removing whole data.

# %%
book_missing["categories"].value_counts().reset_index().sort_values("count", ascending=False)
# Out:
#                      categories  count
# 0                       Fiction   2523
# 1              Juvenile Fiction    534
# 2     Biography & Autobiography    391
# 3                       History    258
# 4            Literary Criticism    164
# ..                          ...    ...
# 519  Adventure stories, English      1
# 518                     Germany      1
# 517                       Egypt      1
# 516                  Apartments      1
# 515                       Books      1
#
# [531 rows x 2 columns]

# %%
book_missing.loc[:, "words_in_description"] = (
    book_missing["description"].str.split().str.len()
)

# %%
book_missing_25_words = book_missing[book_missing["words_in_description"] >= 25]

# %%
book_missing_25_words["title_and_subtitle"] = (
    np.where(book_missing_25_words["subtitle"].isna(), book_missing_25_words["title"],
             book_missing_25_words[["title", "subtitle"]].astype(str).agg(": ".join, axis=1))
)

# %%
book_missing_25_words["tagged_description"] = book_missing_25_words[["isbn13", "description"]].astype(str).agg(" ".join, axis=1)

# %%
book_missing_25_words.drop(["subtitle", "missing_desc", "age_of_book", "words_in_description"], axis=1).to_csv("books_cleaned.csv", index=False)

# %%
pd.read_csv("books_cleaned.csv")
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# ...
